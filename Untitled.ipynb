# %%
import pandas as pd
import numpy as np

a = pd.read_csv('tweets.csv')

# %%
a.createdate = a.createdate.apply(lambda x: np.datetime64(x))

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 9 columns):
# Unnamed: 0    98 non-null int64
# text          98 non-null object
# id            98 non-null int64
# createdate    98 non-null datetime64[ns]
# source        98 non-null object
# likes         98 non-null int64
# retweets      98 non-null int64
# followers     98 non-null int64
# sentiment     98 non-null object
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 7.0+ KB

# %%
a.createdate[0] > np.datetime64('2005-02-25')
# Out:
# True

# %%
a
# Out:
#     Unnamed: 0                                               text  \
# 0            0  keenum california wake up you guys start voter...
# 1            1  emotional neil robertson fight back tear crown...
# 2            2  georgia republican lieutenant governor rip tru...
# 3            3  thing crack trump want important state 2 disre...
# 4            4  fight fight trump trump win we never surrender be
# 5            5  unproven be really serious imagine sleepy joe ...
# 6            6  but act not talk take control step put trump r...
# 7            7  eternal hell trump put position protect find m...
# 8            8              baba 22 ke padh naa xixingping always
# 9            9             the amount polygon trump cause anxiety
# 10          10  fight fight trump trump win we never surrender be
# 11          11  trump promise best stimulus package youve ever...
# 12          12                 1 yeah kind amaze 48 judge look wh
# ...

# %%
a['createdate'][0]> np.datetime64('2005-02-25')
# Out:
# True
